# %% [markdown]
# ## 0. import

# %%
# %matplotlib inline
import cv2
import numpy as np
import os
import glob
from matplotlib import pyplot as plt

# %% [markdown]
# ## 0-1. os path

# %%
import os
print(os.getcwd())
# Out:
# D:\jupyter_notebook\captcha_breaker-review

# %% [markdown]
# ## 0-2. img_show

# %%
def img_show(img):
    fig = plt.figure() # 建立一個Figure（空的顯示區） 
#     print("shape = ",img.shape)
    plt.imshow(img)
    plt.xticks([])
    plt.yticks([])
    plt.show()

# %% [markdown]
# ## 1-0. RGB 原圖

# %%
datasets = glob.glob("./datasets/captcha_original/*.png")

data_no = 2

# i = 0
# for idx, data in enumerate(datasets):

img = cv2.imread(datasets[data_no]) #讀進來BGR
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) #BGR編碼轉 RGB 

img_show(img)

# i = i + 1
# if(i > data_num):
#     break

# %% [markdown]
# ## 1-1. 轉灰階讀入

# %%
data_no = 0

img = cv2.imread(datasets[data_no], 0) #讀進來灰階
img_show(img)

# %% [markdown]
# ## 2. threshold 圖片二值化

# %%
ret, thresh = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY_INV)
img_show(thresh)

# %% [markdown]
# ## 3. findContours 找邊框

# %%
# findContours
contour_img, contours, hierarchy = cv2.findContours(thresh, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
cnt = 0
contour_list = []

for ele in contours:        
    [x,y,w,h] = cv2.boundingRect(ele) #多邊形轉方形
    if  h > 20: # 文字至少要有超過"20"的高度 (不夠高 = 誤判)
        print("[x,y,w,h] =",[x,y,w,h])
        
        # 各邊緣加大 10 pixels
        # 方框劃上去
        cv2.rectangle(contour_img, (x - 10, y - 10), (x + w + 10, y + h + 10), (0, 0, 0), 2)
        # 截圖(方框)
        roi = contour_img[y - 10 : y + h + 10, x - 10 : x + w + 10]
        img_show(roi)
        contour_list.append(roi) # 保存結果
        cnt = cnt + 1
# Out:
# [x,y,w,h] = [136, 67, 28, 26]
# [x,y,w,h] = [45, 64, 25, 22]
# [x,y,w,h] = [132, 62, 29, 25]
# [x,y,w,h] = [186, 52, 30, 30]
# [x,y,w,h] = [368, 43, 14, 21]
# [x,y,w,h] = [280, 24, 28, 32]

# %%
# results
img_show(contour_img)

# %% [markdown]
# ## 4. model testing

# %%
from keras.models import load_model

model = load_model('./3_model_training_and_testing/model-save/mnist.h5')
# Out:
# Using TensorFlow backend.

# %%
def img_resize(img):
    return cv2.resize(img, (28, 28))

# %%
def img_normalize(img):
    return img / 255

# %%
def test_model(img):
    img_show(img)
    
    digit = img.reshape(1, 28, 28, 1).astype('float32')
    pred = model.predict_classes(digit)
    
    print("prediction: ", pred)
    return str(pred[0])

# %%
img_norm_list = []
prediction_list = []
for roi in contour_list:
    img_norm = img_normalize(img_resize(roi))
    img_norm_list.append(img_norm)
    pred = test_model(img_norm)
    prediction_list.append(pred)
# Out:
# prediction:  [2]
# prediction:  [9]
# prediction:  [0]
# prediction:  [0]
# prediction:  [5]
# prediction:  [8]

# %%
def plot_images_prediction(images, prediction, num):
    fig = plt.gcf()
    fig.set_size_inches(15, 20)
    for idx in range(num):
        ax = plt.subplot(10, 10, 1 + idx)
        ax.imshow(images[idx])
        title = 'Predict: ' + str(prediction[idx])
        ax.set_title(title, fontsize = 10)
        ax.set_xticks([])
        ax.set_yticks([])
        idx += 1
    plt.show()

# %%
plot_images_prediction(img_norm_list, prediction_list, 6)
